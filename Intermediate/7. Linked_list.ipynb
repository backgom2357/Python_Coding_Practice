# %% [markdown]
# # Linked list

# %% [markdown]
# ## Linked list
#
# - 리스트
#     - 순서를 가진 데이터의 묶음 : 같은 데이터의 중복 저장가능
#     - 시퀀스 자료형 - 인덱싱, 슬라이싱, 연산자, 메서드 사용 가능
#     - 크기제한 없음, 타입제한 없음
#     - 동적 배열로 작성된 순차 리스트
#     - 자료의 삽입, 삭제 연산시 원소의 이동 작업이 필요
#     - 원소의 개수가 많아시면 연산에 소요되는 시간이 크게 증가
# - 리스트 복사
#     - new_list = old_list : 주소의 복사, 얕은 복사
#     - new_list = old_list[:] : 슬라이싱, 깊은 복사, 깊은 복사중 가장 빠름
#     - new_list = []; new_list.extend(old_list) : (extend() : 리스트를 추가하는 함수), 깊은 복사
#     - new_list = list(old_list) : list(), 깊은 복사
#     - import copy; new_list = copy.copy(old_list) : copy활용, 깊복
#     - new_list = [i for i in old_list] : 리스트 함축, 깊복
#     - import copy; now_list = copy deepcopy(old_list) : 리스트 원소까지도 깊은복사. 가장 느림. 메모리 많이씀. 원본리스트에 포함된 원소들의 객체까지 복사
# - 연결리스트 : 리스트의 단점을 보완한 자료구조
#     - 자료의 논리적인 순서와 메모리 상의 물리적인 순서가 일치하지 않고, 개별적으로 위치하고 있는 원소의 주소를 연결하여 하나의 전체적인 자료구조를 이룸
#     - 링크를 통해 원소에 접근하므로, 순차 리스트에서 물리적인 순서를 맞추기 위한 작업이 필요하지 않음
#     - 자료구조의 크기를 동적으로 조정할 수 있어, 메모리의 효율적인 사용이 가능
#     - 탐색 : 순차탐색
# - 연결리스트의 주요함수
#     - addtoFirst() : 연결리스트의 앞쪽에 원소를 추가하는 연산
#     - addtoLast() : 연결리스트의 뒤쪽에 원소를 추가하는 연산
#     - add() : 연결리스트의 특정 위치에 원소를 추가하는 연산
#     - delete() : 연결리스트의 특정 위치에 있는 원소를 삭제하는 연산
#     - get() : 연결리스트의 특정 위치에 있는 원소를 리턴하는 연산
# - 노드 : 연결리스트에서 하나의 원소에 필요한 데이터를 갖고 있는 자료단위
#     - 데이터 필드 : 원소의 값을 저장하는 자료구조
#     - 링크 필드 : 다음 노드의 주소를 저장하는 자료구조
# - 헤드 : 리스트의 처음 노드를 가리키는 레퍼런스
# - 단순 연결 리스트
#     - 노드가 하나의 링크 필드에 의해 다음 노드와 연결되는 구조를 가짐
#     - 헤드가 가장 앞의 노드를 가리키고, 각 노드의 링크 필드가 연속적으로 다음 노드를 가리킴
#     - 최종적으로 None을 가리키는 노드가 리스트의 가장 마지막 노드임
# - 이중 연결 리스트
#     - 양쪽 방향으로 순회할 수 있도록 노드를 연결한 리스트
#     - 두 개의 링크 필드와 한 개의 데이터 필드로 구성

# %% [markdown]
# ## 삽입 정렬
#
# - 삽입 정렬의 특징 : 자료 배열의 모든 원소들을 앞에서부터 차례대로 이미 정렬된 부분과 비교화여, 자신의 위치를 찾아냄으로써 정렬을 완성
# - 정렬 과정
#     - 정렬할 자료를 두개의 부분 집합 S, U로 가정
#         - S : 정렬된 앞부분의 원소들
#         - U : 정렬 안된 나머지 원소들
#     - 정렬되지 않은 부분집합 U의 원소를 하나씩 꺼내서 이미 정렬되어있는 부분집합 S의 마지막 원소부터 비교하면서 위치를 찾아 삽입
#     - 삽입 정렬을 반복하면서 부분집합 S의 원소는 하나씩 늘리고 부분집합 U의 원소는 하나씩 감소하게 함
#     - U가 공집합이 되면 삽입정렬이 완성
#     - 시간복잡도 O(n^2)

# %% [markdown]
# ## 병합 정렬
# - 병합 정렬의 특징 : 여러 개의 정렬된 자료의 집합을 병합하여 한 개의 정렬된 집합으로 만드는 방식
#     - 분할 정복 알고리즘 활용
#         - 자료를 최소 단위의 문제까지 나눈 후에 차례대로 정렬하여 최종 결과를 얻어냄
#         - Top-Down 방식
#     - 시간 복잡도
#         - O(n log n)

# %% [markdown]
# ## Linked List의 활용
#
# - List를 이용한 Stack
#     - 스택의 원소 : 리스트의 노드
#         - 스택 내의 순서는 리스트의 링크를 통해 연결됨
#         - Push : 리스트의 마지막에 노드 삽입
#         - Pop : 리스트의 마지막 노드 반환/삭제
#     - 변수 Top
#         - 리스트의 마지막 노드를 가리키는 변수
#         - 초기 상태: Top = None
# - 연결리스트를 이용한 우선순위 큐

# %% [markdown]
# ### 숫자 추가

# %%
# T = int(input())

f = open("cases.txt", "r")
T = int(f.readline())


class Node:
    def __init__(self, data):
        self.data = data
        self.link = None


class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def addtoLast(self, node):
        if self.head == None:
            self.head = node
        else:
            cur = self.head
            while cur.link != None:
                cur = cur.link
            cur.link = node

    def add(self, node, index):
        idx = 0
        cur = self.head
        n = node

        if index == 0:
            n.link = cur
            self.head = n
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                n.link = cur.link
                cur.link = n
                return 0
            cur = cur.link

        return -1

    def get(self, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        while cur.link != None:
            if idx == index:
                return cur.data
            cur = cur.link
            idx += 1

        return cur.data


for case in range(1, T + 1):

    N, M, L = map(int,f.readline().split())

    array = list(map(int, f.readline().split()[:N]))

    ll = SinglyLinkedList()

    for c in array:
        ll.addtoLast(Node(c))

    for _ in range(M):
        idx, data = map(int, f.readline().split())
        ll.add(Node(data), idx)

    print("#%d"%case, ll.get(L))


f.close()

# %% [markdown]
# ### 수열 합치기

# %%
# T = int(input())

f = open("cases.txt", "r")
T = int(f.readline())


class Node:
    def __init__(self, data):
        self.data = data
        self.link = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.count = 0

    def addtoLast(self, node):
        if self.head == None:
            self.head = node
            self.count += 1
        else:
            cur = self.head
            while cur.link != None:
                cur = cur.link
            cur.link = node
            self.count += 1

    def add(self, node, index):
        idx = 0
        cur = self.head
        n = node

        if index == 0:
            n.link = cur
            self.head = n
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                n.link = cur.link
                cur.link = n
                self.count += 1
                return 0
            cur = cur.link

        return -1

    def addContinuously(self, dataList, index):
        idx = 0
        cur = self.head
        n0 = Node(dataList[0])
        cur_in_dataList = n0

        for data in dataList[1:]:
            cur_in_dataList.link = Node(data)
            cur_in_dataList = cur_in_dataList.link
            self.count += 1

        if index == 0:
            cur_in_dataList.link = cur
            self.head = n0
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                cur_in_dataList.link = cur.link
                cur.link = n0
                self.count += 1
                return 0
            cur = cur.link

        cur.link = n0
        self.count += 1

        return -1

    def get(self, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        while cur.link != None:
            if idx == index:
                return cur.data
            cur = cur.link
            idx += 1

        return cur.data

    def getLast10Node(self):
        tmp = []

        idx = 0
        cur = self.head
        while cur.link != None:
            if idx >= self.count - 10:
                tmp.append(cur.data)
            cur = cur.link
            idx += 1
        tmp.append(cur.data)

        return tmp


for case in range(1, T + 1):

    N, M = map(int,f.readline().split())

    sll = SinglyLinkedList()
    nums = list(map(int, f.readline().split()))

    for i in range(N):
        sll.addtoLast(Node(nums[i]))

    for _ in range(M-1):
        nums = list(map(int, f.readline().split()))
        idx = 0

        # print("count", sll.count, "idx", idx)

        while idx < sll.count:
            # print(sll.get(idx), nums[0])
            if sll.get(idx) > nums[0]:
                break
            idx += 1

        # print("index : ", idx)
        # print("nums", nums)

        sll.addContinuously(nums, idx)

        # print([sll.get(c) for c in range(sll.count)])
        # print()

    result = sll.getLast10Node()

    print("#%d"%case, result[9], result[8], result[7], result[6], result[5], result[4], result[3], result[2], result[1], result[0])

f.close()

# %% [markdown]
# ### 암호

# %%
# T = int(input())

f = open("cases.txt", "r")
T = int(f.readline())


class Node:
    def __init__(self, data):
        self.data = data
        self.link = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.count = 0

    def addtoLast(self, node):
        if self.head == None:
            self.head = node
            self.count += 1
        else:
            cur = self.head
            while cur.link != None:
                cur = cur.link
            cur.link = node
            self.count += 1

    def add(self, node, index):
        idx = 0
        cur = self.head
        n = node

        if index == 0:
            n.link = cur
            self.head = n
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                n.link = cur.link
                cur.link = n
                self.count += 1
                return 0
            cur = cur.link

        n.link = cur.link
        cur.link = n
        self.count += 1
        return 0

    def addContinuously(self, dataList, index=0):
        idx = 0
        cur = self.head
        n0 = Node(dataList[0])
        cur_in_dataList = n0

        for data in dataList[1:]:
            cur_in_dataList.link = Node(data)
            cur_in_dataList = cur_in_dataList.link
            self.count += 1

        if index == 0:
            cur_in_dataList.link = cur
            self.head = n0
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                cur_in_dataList.link = cur.link
                cur.link = n0
                self.count += 1
                return 0
            cur = cur.link

        cur.link = n0
        self.count += 1

        return -1

    def sum_a_n_b(self, a, b):
        idx = 0
        sum = 0
        cur = self.head
        count = 0
        if self.head == None:
            return -1
        while cur.link != None:
            if idx == a or idx == b:
                sum += cur.data
                count += 1
            if count == 2:
                return sum
            cur = cur.link
            idx += 1

        if idx == a or idx == b:
            sum += cur.data
        return sum

    def get(self, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        while cur.link != None:
            if idx == index:
                return cur.data
            cur = cur.link
            idx += 1

        return cur.data

    def get_last_n_nodes(self, n, reverse = False):
        tmp = []

        idx = 0
        cur = self.head
        while cur.link != None:
            if idx >= self.count - n:
                tmp = [cur.data] + tmp
            cur = cur.link
            idx += 1
        tmp = [cur.data] + tmp

        if reverse == True:
            tmp.reverse()

        return tmp


for case in range(1, T + 1):

    N, M, K = map(int, f.readline().split())

    nums = list(map(int, f.readline().split()))

    sll = SinglyLinkedList()

    sll.addContinuously(nums)

    idx = M
    count = K
    # print(sll.get_last_n_nodes(sll.count, True))
    while count:
        data = sll.sum_a_n_b((idx-1)%sll.count, idx%sll.count)
        # print("data", data, "idx", idx, "sll.count :", sll.count)

        if idx == 0:
            idx = (idx-1)%(sll.count+1)
            sll.add(Node(data), idx)
        else:
            sll.add(Node(data), idx)
        count -= 1
        # print(sll.get_last_n_nodes(sll.count, True))
        idx = (idx + M) % (sll.count)

    print("#%d"%case, " ".join(map(str,sll.get_last_n_nodes(10))))


f.close()

# %% [markdown]
# ### 수열 편집

# %%
# T = int(input())

f = open("cases.txt", "r")
T = int(f.readline())


class Node:
    def __init__(self, data):
        self.data = data
        self.link = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.count = 0

    def addtoLast(self, node):
        if self.head == None:
            self.head = node
            self.count += 1
        else:
            cur = self.head
            while cur.link != None:
                cur = cur.link
            cur.link = node
            self.count += 1

    def add(self, node, index):
        idx = 0
        cur = self.head
        n = node

        if index == 0:
            n.link = cur
            self.head = n
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                n.link = cur.link
                cur.link = n
                self.count += 1
                return 0
            cur = cur.link

        n.link = cur.link
        cur.link = n
        self.count += 1
        return 0

    def addContinuously(self, dataList, index=0):
        idx = 0
        cur = self.head
        n0 = Node(dataList[0])
        cur_in_dataList = n0

        for data in dataList[1:]:
            cur_in_dataList.link = Node(data)
            cur_in_dataList = cur_in_dataList.link
            self.count += 1

        if index == 0:
            cur_in_dataList.link = cur
            self.head = n0
            self.count += 1
            return 0

        while cur.link != None:
            idx += 1
            if idx == index:
                cur_in_dataList.link = cur.link
                cur.link = n0
                self.count += 1
                return 0
            cur = cur.link

        cur.link = n0
        self.count += 1

        return -1

    def sum_a_n_b(self, a, b):
        idx = 0
        sum = 0
        cur = self.head
        count = 0
        if self.head == None:
            return -1
        while cur.link != None:
            if idx == a or idx == b:
                sum += cur.data
                count += 1
            if count == 2:
                return sum
            cur = cur.link
            idx += 1

        if idx == a or idx == b:
            sum += cur.data
        return sum

    def get(self, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        while cur != None:
            if idx == index:
                return cur.data
            cur = cur.link
            idx += 1

        return -1

    def get_last_n_nodes(self, n, reverse = False):
        tmp = []

        idx = 0
        cur = self.head
        while cur.link != None:
            if idx >= self.count - n:
                tmp = [cur.data] + tmp
            cur = cur.link
            idx += 1
        tmp = [cur.data] + tmp

        if reverse == True:
            tmp.reverse()

        return tmp

    def delete(self, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        if index == 0:
            self.head = cur.link
            self.count -= 1
            return 0
        while cur != None:
            if idx + 1 == index:
                cur.link = cur.link.link
                self.count -= 1
                return 0
            idx += 1
            cur = cur.link
        return 0

    def change(self,data, index):
        idx = 0
        cur = self.head
        if self.head == None:
            return -1
        while cur != None:
            if idx == index:
                cur.data = data
                return 0

            idx += 1
            cur = cur.link

        return -1


for case in range(1, T + 1):

    N, M, L = map(int, f.readline().split())

    nums = list(map(int, f.readline().split()))
    result = -1

    sll = SinglyLinkedList()
    sll.addContinuously(nums)

    for _ in range(M):

        edit = list(f.readline().split())

        if edit[0] == "I":
            sll.add(Node(int(edit[2])), int(edit[1]))
        elif edit[0] == "D":
            sll.delete(int(edit[1]))
        else:
            sll.change(int(edit[2]), int(edit[1]))

        print(edit)
        print(sll.get_last_n_nodes(sll.count,True))

    result = sll.get(L)

    print("#%d"%case, result)



f.close()
